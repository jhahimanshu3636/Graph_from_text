# %%
import pandas as pd
from graph_maker import GraphMaker, Ontology, GroqClient, OpenAIClient
from graph_maker import Document

# %% [markdown]
# ### Data formation from text file

# %%
def read_file_chunks(filename, chunk_size):
    chunks = []
    with open(filename, 'r') as file:
        while True:
            chunk = file.read(chunk_size)
            if not chunk:
                break
            chunks.append(chunk)
    return chunks

filename = 'input_data/sample_article.txt'  # Replace 'your_file.txt' with the path to your .txt file
chunk_size = 200  # Adjust this value as per your requirement
chunks = read_file_chunks(filename, chunk_size)

# %%
len(chunks)
# Out:
# 20

# %% [markdown]
# ### Ontology

# %%
ontology = Ontology(
    labels=[
        {"Person": "Person name without any adjectives, Remember a person may be referenced by their name or using a pronoun"},
        {"Event": "Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc."},
        "Organisation",
        {"Funding Round": "Round of funking Like seed funding,series A functing etc."},
        {"Funding Type" : 'type of funding like equity funding , debt funding etc.'},
        {"Miscellaneous": "Any important concept can not be categorised with any other given label"},
    ],
    relationships=[
        "Any kind of relation that would directly connect or indirectly connect the entity nodes to Funded Organization node",
        "Any kind of relationship that would connect Funded Organzation to entity that represents the companies working and features"
        ],
)

# %% [markdown]
# ### Creating documents from chunked text

# %%
model ="llama3-8b-8192"

import datetime
current_time = str(datetime.datetime.now())

# Use Groq
llm = GroqClient(model=model, temperature=0.1, top_p=0.5)


graph_maker = GraphMaker(ontology=ontology, llm_client=llm, verbose=False)

def generate_summary(text):
    SYS_PROMPT = (
        "Succintly summarise the text provided by the user. "
        "Respond only with the summary and no other comments"
    )
    try:
        summary = llm.generate(user_message=text, system_message=SYS_PROMPT)
    except:
        summary = ""
    finally:
        return summary


docs = map(
    lambda t: Document(text=t, metadata={"summary": generate_summary(t), 'generated_at': current_time}),
    chunks
)

# %%
generate_summary(chunks[1])
# Out:
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 'Stanza Living, a Delhi-based startup, is raising Rs 110 crore by issuing 1,207 preference shares at Rs 911440.17 each.'

# %% [markdown]
# ### Creating graph

# %%
graph = graph_maker.from_documents(
    list(docs), 
    delay_s_between=1 ## delay_s_between because otherwise groq api maxes out pretty fast. 
    ) 
print("Total number of Edges", len(graph))
# Out:
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:33 - INFO
# Document: 1
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:33 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives,this person will be associated or connected with a organization ,Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organisation', 'Action', {'Miscellaneous': 'Any important concept can not be categorised with any other given label'}] relationships=['Relation between any pair of Entities, every node should be having a relationship']
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:34 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Organisation", "name": "Alpha Wave"},
#         "relationship": "Stanza Living has received investment from Alpha Wave"
#     },
#     {
#         "node_1": {"label": "Person", "name": "Stanza Living"},
#         "node_2": {"label": "Event", "name": "equity round"},
#         "relationship": "Stanza Living has participated in an equity round"
#     },
#     {
#         "node_1": {"label": "Person", "name": "Stanza Living"},
#         "node_2": {"label": "Object", "name": "Rs 110 crore"},
#         "relationship": "Stanza Living has received Rs 110 crore"
#     },
#     {
#         "node_1": {"label": "Person", "name": "Stanza Living"},
#         "node_2": {"label": "Action", "name": "raised"},
#         "relationship": "Stanza Living has raised funds"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:34 - INFO
# Trying JSON Parsing:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Organisation", "name": "Alpha Wave"},
#         "relationship": "Stanza Living has received investment from Alpha Wave"
#     },
#     {
#         "node_1": {"label": "Person", "name": "Stanza Living"},
#         "node_2": {"label": "Event", "name": "equity round"},
#         "relationship": "Stanza Living has participated in an equity round"
#     },
#     {
#         "node_1": {"label": "Person", "name": "Stanza Living"},
#         "node_2": {"label": "Object", "name": "Rs 110 crore"},
#         "relationship": "Stanza Living has received Rs 110 crore"
#     },
#     {
#         "node_1": {"label": "Person", "name": "Stanza Living"},
#         "node_2": {"label": "Action", "name": "raised"},
#         "relationship": "Stanza Living has raised funds"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:34 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:34 - INFO
# Waiting for 1s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:35 - INFO
# Document: 2
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:35 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives,this person will be associated or connected with a organization ,Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organisation', 'Action', {'Miscellaneous': 'Any important concept can not be categorised with any other given label'}] relationships=['Relation between any pair of Entities, every node should be having a relationship']
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:35 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Organisation", "name": "Delhi-based startup"},
#         "relationship": "Stanza Living is associated with the Delhi-based startup"
#     },
#     {
#         "node_1": {"label": "Person", "name": "board"},
#         "node_2": {"label": "Organisation", "name": "Stanza Living"},
#         "relationship": "The board is part of Stanza Living"
#     },
#     {
#         "node_1": {"label": "Event", "name": "passing a special resolution"},
#         "node_2": {"label": "Organisation", "name": "Stanza Living"},
#         "relationship": "Stanza Living passed a special resolution"
#     },
#     {
#         "node_1": {"label": "Object", "name": "1,207 preference shares"},
#         "node_2": {"label": "Organisation", "name": "Stanza Living"},
#         "relationship": "Stanza Living issued 1,207 preference shares"
#     },
#     {
#         "node_1": {"label": "Object", "name": "Rs 911440.17"},
#         "node_2": {"label": "Object", "name": "Rs 110 crore"},
#         "relationship": "Rs 911440.17 is the price of Rs 110 crore"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:35 - INFO
# Trying JSON Parsing:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Organisation", "name": "Delhi-based startup"},
#         "relationship": "Stanza Living is associated with the Delhi-based startup"
#     },
#     {
#         "node_1": {"label": "Person", "name": "board"},
#         "node_2": {"label": "Organisation", "name": "Stanza Living"},
#         "relationship": "The board is part of Stanza Living"
#     },
#     {
#         "node_1": {"label": "Event", "name": "passing a special resolution"},
#         "node_2": {"label": "Organisation", "name": "Stanza Living"},
#         "relationship": "Stanza Living passed a special resolution"
#     },
#     {
#         "node_1": {"label": "Object", "name": "1,207 preference shares"},
#         "node_2": {"label": "Organisation", "name": "Stanza Living"},
#         "relationship": "Stanza Living issued 1,207 preference shares"
#     },
#     {
#         "node_1": {"label": "Object", "name": "Rs 911440.17"},
#         "node_2": {"label": "Object", "name": "Rs 110 crore"},
#         "relationship": "Rs 911440.17 is the price of Rs 110 crore"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:35 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:35 - INFO
# Waiting for 1s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:36 - INFO
# Document: 3
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:36 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives,this person will be associated or connected with a organization ,Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organisation', 'Action', {'Miscellaneous': 'Any important concept can not be categorised with any other given label'}] relationships=['Relation between any pair of Entities, every node should be having a relationship']
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:37 - INFO
# LLM Response:
# [
#   {
#     "node_1": {"label": "Organisation", "name": "Alpha Wave"},
#     "node_2": {"label": "Organisation", "name": "Matrix Partners"},
#     "relationship": "Alpha Wave has invested in Matrix Partners"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "Alpha Wave"},
#     "node_2": {"label": "Organisation", "name": "Accel India"},
#     "relationship": "Alpha Wave has invested in Accel India"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "Alpha Wave"},
#     "node_2": {"label": "Organisation", "name": "Peak XV"},
#     "relationship": "Alpha Wave has invested in Peak XV"
#   },
#   {
#     "node_1": {"label": "Person", "name": "g"},
#     "node_2": {"label": "Document", "name": "startup data"},
#     "relationship": "g accessed startup data"
#   }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:37 - INFO
# Trying JSON Parsing:
# [
#   {
#     "node_1": {"label": "Organisation", "name": "Alpha Wave"},
#     "node_2": {"label": "Organisation", "name": "Matrix Partners"},
#     "relationship": "Alpha Wave has invested in Matrix Partners"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "Alpha Wave"},
#     "node_2": {"label": "Organisation", "name": "Accel India"},
#     "relationship": "Alpha Wave has invested in Accel India"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "Alpha Wave"},
#     "node_2": {"label": "Organisation", "name": "Peak XV"},
#     "relationship": "Alpha Wave has invested in Peak XV"
#   },
#   {
#     "node_1": {"label": "Person", "name": "g"},
#     "node_2": {"label": "Document", "name": "startup data"},
#     "relationship": "g accessed startup data"
#   }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:37 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:37 - INFO
# Waiting for 1s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:38 - INFO
# Document: 4
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:38 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives,this person will be associated or connected with a organization ,Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organisation', 'Action', {'Miscellaneous': 'Any important concept can not be categorised with any other given label'}] relationships=['Relation between any pair of Entities, every node should be having a relationship']
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:39 - INFO
# LLM Response:
# [
#   {
#     "node_1": {"label": "Organisation", "name": "TheKredible"},
#     "node_2": {"label": "Organisation", "name": "Stanza Living"},
#     "relationship": "TheKredible is associated with Stanza Living"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "TheKredible"},
#     "node_2": {"label": "Object", "name": "Rs 3,900 crore"},
#     "relationship": "TheKredible is valued at Rs 3,900 crore"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "TheKredible"},
#     "node_2": {"label": "Object", "name": "Rs 3,525 crore"},
#     "relationship": "TheKredible was valued at Rs 3,525 crore in the last equity round"
#   },
#   {
#     "node_1": {"label": "Object", "name": "Rs 3,900 crore"},
#     "node_2": {"label": "Object", "name": "Rs 3,525 crore"},
#     "relationship": "Rs 3,900 crore is a marginal jump in valuation from Rs 3,525 crore"
#   }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:39 - INFO
# Trying JSON Parsing:
# [
#   {
#     "node_1": {"label": "Organisation", "name": "TheKredible"},
#     "node_2": {"label": "Organisation", "name": "Stanza Living"},
#     "relationship": "TheKredible is associated with Stanza Living"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "TheKredible"},
#     "node_2": {"label": "Object", "name": "Rs 3,900 crore"},
#     "relationship": "TheKredible is valued at Rs 3,900 crore"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "TheKredible"},
#     "node_2": {"label": "Object", "name": "Rs 3,525 crore"},
#     "relationship": "TheKredible was valued at Rs 3,525 crore in the last equity round"
#   },
#   {
#     "node_1": {"label": "Object", "name": "Rs 3,900 crore"},
#     "node_2": {"label": "Object", "name": "Rs 3,525 crore"},
#     "relationship": "Rs 3,900 crore is a marginal jump in valuation from Rs 3,525 crore"
#   }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:39 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:39 - INFO
# Waiting for 1s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:40 - INFO
# Document: 5
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:40 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives,this person will be associated or connected with a organization ,Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organisation', 'Action', {'Miscellaneous': 'Any important concept can not be categorised with any other given label'}] relationships=['Relation between any pair of Entities, every node should be having a relationship']
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:41 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Organisation", "name": "Kotak Mahindra Bank"},
#         "relationship": "Stanza Living has a financial relationship with Kotak Mahindra Bank"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Organisation", "name": "RBL Bank"},
#         "relationship": "Stanza Living has a financial relationship with RBL Bank"
#     },
#     {
#         "node_1": {"label": "Person", "name": "unknown"},
#         "node_2": {"label": "Organisation", "name": "Stanza Living"},
#         "relationship": "The person was reportedly in talks to raise funding for Stanza Living"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:41 - INFO
# Trying JSON Parsing:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Organisation", "name": "Kotak Mahindra Bank"},
#         "relationship": "Stanza Living has a financial relationship with Kotak Mahindra Bank"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Organisation", "name": "RBL Bank"},
#         "relationship": "Stanza Living has a financial relationship with RBL Bank"
#     },
#     {
#         "node_1": {"label": "Person", "name": "unknown"},
#         "node_2": {"label": "Organisation", "name": "Stanza Living"},
#         "relationship": "The person was reportedly in talks to raise funding for Stanza Living"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:41 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:41 - INFO
# Waiting for 1s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:42 - INFO
# Document: 6
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:42 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives,this person will be associated or connected with a organization ,Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organisation', 'Action', {'Miscellaneous': 'Any important concept can not be categorised with any other given label'}] relationships=['Relation between any pair of Entities, every node should be having a relationship']
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:42 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Event", "name": "equity round"},
#         "relationship": "Stanza Living participated in an equity round"
#     },
#     {
#         "node_1": {"label": "Person", "name": "unknown"},
#         "node_2": {"label": "Organisation", "name": "Stanza Living"},
#         "relationship": "The person is associated with Stanza Living"
#     },
#     {
#         "node_1": {"label": "Object", "name": "equity round"},
#         "node_2": {"label": "Object", "name": "debt rounds"},
#         "relationship": "Equity round is related to debt rounds"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Place", "name": "unknown"},
#         "relationship": "Stanza Living operates in a place"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:42 - INFO
# Trying JSON Parsing:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Event", "name": "equity round"},
#         "relationship": "Stanza Living participated in an equity round"
#     },
#     {
#         "node_1": {"label": "Person", "name": "unknown"},
#         "node_2": {"label": "Organisation", "name": "Stanza Living"},
#         "relationship": "The person is associated with Stanza Living"
#     },
#     {
#         "node_1": {"label": "Object", "name": "equity round"},
#         "node_2": {"label": "Object", "name": "debt rounds"},
#         "relationship": "Equity round is related to debt rounds"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Place", "name": "unknown"},
#         "relationship": "Stanza Living operates in a place"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:42 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:42 - INFO
# Waiting for 1s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:43 - INFO
# Document: 7
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:43 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives,this person will be associated or connected with a organization ,Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organisation', 'Action', {'Miscellaneous': 'Any important concept can not be categorised with any other given label'}] relationships=['Relation between any pair of Entities, every node should be having a relationship']
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:44 - INFO
# LLM Response:
# [
#   {
#     "node_1": {"label": "Organisation", "name": "Stanza Living"},
#     "node_2": {"label": "Organisation", "name": "The firm"},
#     "relationship": "Stanza Living is the same as The firm"
#   },
#   {
#     "node_1": {"label": "Person", "name": "professionals"},
#     "node_2": {"label": "Person", "name": "students"},
#     "relationship": "professionals and students are two groups of people"
#   },
#   {
#     "node_1": {"label": "Object", "name": "75,000 beds"},
#     "node_2": {"label": "Object", "name": "450 plus residences"},
#     "relationship": "75,000 beds and 450 plus residences are two different objects"
#   },
#   {
#     "node_1": {"label": "Place", "name": "24 cities"},
#     "node_2": {"label": "Organisation", "name": "Stanza Living"},
#     "relationship": "Stanza Living has a presence across 24 cities"
#   }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:44 - INFO
# Trying JSON Parsing:
# [
#   {
#     "node_1": {"label": "Organisation", "name": "Stanza Living"},
#     "node_2": {"label": "Organisation", "name": "The firm"},
#     "relationship": "Stanza Living is the same as The firm"
#   },
#   {
#     "node_1": {"label": "Person", "name": "professionals"},
#     "node_2": {"label": "Person", "name": "students"},
#     "relationship": "professionals and students are two groups of people"
#   },
#   {
#     "node_1": {"label": "Object", "name": "75,000 beds"},
#     "node_2": {"label": "Object", "name": "450 plus residences"},
#     "relationship": "75,000 beds and 450 plus residences are two different objects"
#   },
#   {
#     "node_1": {"label": "Place", "name": "24 cities"},
#     "node_2": {"label": "Organisation", "name": "Stanza Living"},
#     "relationship": "Stanza Living has a presence across 24 cities"
#   }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:44 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:44 - INFO
# Waiting for 1s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:45 - INFO
# Document: 8
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:45 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives,this person will be associated or connected with a organization ,Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organisation', 'Action', {'Miscellaneous': 'Any important concept can not be categorised with any other given label'}] relationships=['Relation between any pair of Entities, every node should be having a relationship']
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:46 - INFO
# LLM Response:
# [
#   {
#     "node_1": {"label": "Organisation", "name": "TheKredible"},
#     "node_2": {"label": "Organisation", "name": "The firm"},
#     "relationship": "TheKredible is related to the firm"
#   },
#   {
#     "node_1": {"label": "Person", "name": "s"},
#     "node_2": {"label": "Organisation", "name": "TheKredible"},
#     "relationship": "s is associated with TheKredible"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "TheKredible"},
#     "node_2": {"label": "Event", "name": "FY23"},
#     "relationship": "TheKredible is involved in FY23"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "TheKredible"},
#     "node_2": {"label": "Event", "name": "FY22"},
#     "relationship": "TheKredible is involved in FY22"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "TheKredible"},
#     "node_2": {"label": "Action", "name": "file"},
#     "relationship": "TheKredible needs to file"
#   }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:46 - INFO
# Trying JSON Parsing:
# [
#   {
#     "node_1": {"label": "Organisation", "name": "TheKredible"},
#     "node_2": {"label": "Organisation", "name": "The firm"},
#     "relationship": "TheKredible is related to the firm"
#   },
#   {
#     "node_1": {"label": "Person", "name": "s"},
#     "node_2": {"label": "Organisation", "name": "TheKredible"},
#     "relationship": "s is associated with TheKredible"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "TheKredible"},
#     "node_2": {"label": "Event", "name": "FY23"},
#     "relationship": "TheKredible is involved in FY23"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "TheKredible"},
#     "node_2": {"label": "Event", "name": "FY22"},
#     "relationship": "TheKredible is involved in FY22"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "TheKredible"},
#     "node_2": {"label": "Action", "name": "file"},
#     "relationship": "TheKredible needs to file"
#   }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:46 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:46 - INFO
# Waiting for 1s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:47 - INFO
# Document: 9
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:47 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives,this person will be associated or connected with a organization ,Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organisation', 'Action', {'Miscellaneous': 'Any important concept can not be categorised with any other given label'}] relationships=['Relation between any pair of Entities, every node should be having a relationship']
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:48 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Organisation", "name": "Colive"},
#         "relationship": "Stanza Living competes with Colive"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Organisation", "name": "Your Space"},
#         "relationship": "Stanza Living competes with Your Space"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Organisation", "name": "Settl"},
#         "relationship": "Stanza Living competes with Settl"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Organisation", "name": "Union Living"},
#         "relationship": "Stanza Living competes with Union Living"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Organisation", "name": "Coho"},
#         "relationship": "Stanza Living competes with Coho"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "NestAway"},
#         "node_2": {"label": "Organisation", "name": "Aurum PropTech"},
#         "relationship": "NestAway was acquired by Aurum PropTech"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:48 - INFO
# Trying JSON Parsing:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Organisation", "name": "Colive"},
#         "relationship": "Stanza Living competes with Colive"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Organisation", "name": "Your Space"},
#         "relationship": "Stanza Living competes with Your Space"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Organisation", "name": "Settl"},
#         "relationship": "Stanza Living competes with Settl"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Organisation", "name": "Union Living"},
#         "relationship": "Stanza Living competes with Union Living"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Stanza Living"},
#         "node_2": {"label": "Organisation", "name": "Coho"},
#         "relationship": "Stanza Living competes with Coho"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "NestAway"},
#         "node_2": {"label": "Organisation", "name": "Aurum PropTech"},
#         "relationship": "NestAway was acquired by Aurum PropTech"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:48 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:48 - INFO
# Waiting for 1s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:49 - INFO
# Document: 10
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:49 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives,this person will be associated or connected with a organization ,Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organisation', 'Action', {'Miscellaneous': 'Any important concept can not be categorised with any other given label'}] relationships=['Relation between any pair of Entities, every node should be having a relationship']
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:50 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Majesco Ltd"},
#         "node_2": {"label": "Organisation", "name": "Propelld"},
#         "relationship": "Majesco Ltd is related to Propelld as an investor"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Propelld"},
#         "node_2": {"label": "Organisation", "name": "Edgro"},
#         "relationship": "Propelld owns Edgro"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Edgro"},
#         "node_2": {"label": "Object", "name": "NBFC subsidiary"},
#         "relationship": "Edgro is a type of NBFC subsidiary"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Propelld"},
#         "node_2": {"label": "Object", "name": "$25 million debt funding"},
#         "relationship": "Propelld received $25 million debt funding"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:50 - INFO
# Trying JSON Parsing:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Majesco Ltd"},
#         "node_2": {"label": "Organisation", "name": "Propelld"},
#         "relationship": "Majesco Ltd is related to Propelld as an investor"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Propelld"},
#         "node_2": {"label": "Organisation", "name": "Edgro"},
#         "relationship": "Propelld owns Edgro"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Edgro"},
#         "node_2": {"label": "Object", "name": "NBFC subsidiary"},
#         "relationship": "Edgro is a type of NBFC subsidiary"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Propelld"},
#         "node_2": {"label": "Object", "name": "$25 million debt funding"},
#         "relationship": "Propelld received $25 million debt funding"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:50 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:50 - INFO
# Waiting for 1s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:51 - INFO
# Document: 11
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:51 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives,this person will be associated or connected with a organization ,Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organisation', 'Action', {'Miscellaneous': 'Any important concept can not be categorised with any other given label'}] relationships=['Relation between any pair of Entities, every node should be having a relationship']
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:groq._base_client:Retrying request to /openai/v1/chat/completions in 1.000000 seconds
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:53 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Person", "name": "dgro"},
#         "node_2": {"label": "Organisation", "name": "Credit Saison India Private Limited"},
#         "relationship": "dgro is associated with Credit Saison India Private Limited"
#     },
#     {
#         "node_1": {"label": "Person", "name": "dgro"},
#         "node_2": {"label": "Organisation", "name": "AU Small Finance Bank"},
#         "relationship": "dgro is associated with AU Small Finance Bank"
#     },
#     {
#         "node_1": {"label": "Person", "name": "dgro"},
#         "node_2": {"label": "Organisation", "name": "InCred Financial Services Limited"},
#         "relationship": "dgro is associated with InCred Financial Services Limited"
#     },
#     {
#         "node_1": {"label": "Person", "name": "dgro"},
#         "node_2": {"label": "Organisation", "name": "Northern Arc Capital Limited"},
#         "relationship": "dgro is associated with Northern Arc Capital Limited"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:53 - INFO
# Trying JSON Parsing:
# [
#     {
#         "node_1": {"label": "Person", "name": "dgro"},
#         "node_2": {"label": "Organisation", "name": "Credit Saison India Private Limited"},
#         "relationship": "dgro is associated with Credit Saison India Private Limited"
#     },
#     {
#         "node_1": {"label": "Person", "name": "dgro"},
#         "node_2": {"label": "Organisation", "name": "AU Small Finance Bank"},
#         "relationship": "dgro is associated with AU Small Finance Bank"
#     },
#     {
#         "node_1": {"label": "Person", "name": "dgro"},
#         "node_2": {"label": "Organisation", "name": "InCred Financial Services Limited"},
#         "relationship": "dgro is associated with InCred Financial Services Limited"
#     },
#     {
#         "node_1": {"label": "Person", "name": "dgro"},
#         "node_2": {"label": "Organisation", "name": "Northern Arc Capital Limited"},
#         "relationship": "dgro is associated with Northern Arc Capital Limited"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:53 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:53 - INFO
# Waiting for 1s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:54 - INFO
# Document: 12
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:54 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives,this person will be associated or connected with a organization ,Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organisation', 'Action', {'Miscellaneous': 'Any important concept can not be categorised with any other given label'}] relationships=['Relation between any pair of Entities, every node should be having a relationship']
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:groq._base_client:Retrying request to /openai/v1/chat/completions in 1.000000 seconds
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:56 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Person", "name": "Bibhu Prasad Das"},
#         "node_2": {"label": "Organisation", "name": "Propelld"},
#         "relationship": "Bibhu Prasad Das is a co-founder of Propelld"
#     },
#     {
#         "node_1": {"label": "Person", "name": "Victor Senapaty"},
#         "node_2": {"label": "Organisation", "name": "Propelld"},
#         "relationship": "Victor Senapaty is a co-founder of Propelld"
#     },
#     {
#         "node_1": {"label": "Person", "name": "Brijesh Samantaray"},
#         "node_2": {"label": "Organisation", "name": "Propelld"},
#         "relationship": "Brijesh Samantaray is a co-founder of Propelld"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Propelld"},
#         "node_2": {"label": "Event", "name": "Founded"},
#         "relationship": "Propelld was founded"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:56 - INFO
# Trying JSON Parsing:
# [
#     {
#         "node_1": {"label": "Person", "name": "Bibhu Prasad Das"},
#         "node_2": {"label": "Organisation", "name": "Propelld"},
#         "relationship": "Bibhu Prasad Das is a co-founder of Propelld"
#     },
#     {
#         "node_1": {"label": "Person", "name": "Victor Senapaty"},
#         "node_2": {"label": "Organisation", "name": "Propelld"},
#         "relationship": "Victor Senapaty is a co-founder of Propelld"
#     },
#     {
#         "node_1": {"label": "Person", "name": "Brijesh Samantaray"},
#         "node_2": {"label": "Organisation", "name": "Propelld"},
#         "relationship": "Brijesh Samantaray is a co-founder of Propelld"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Propelld"},
#         "node_2": {"label": "Event", "name": "Founded"},
#         "relationship": "Propelld was founded"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:56 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:56 - INFO
# Waiting for 1s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:57 - INFO
# Document: 13
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:57 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives,this person will be associated or connected with a organization ,Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organisation', 'Action', {'Miscellaneous': 'Any important concept can not be categorised with any other given label'}] relationships=['Relation between any pair of Entities, every node should be having a relationship']
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:groq._base_client:Retrying request to /openai/v1/chat/completions in 1.000000 seconds
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:34:59 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "NBFC"},
#         "node_2": {"label": "Organisation", "name": "company"},
#         "relationship": "NBFC is an arm of the company"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "company"},
#         "node_2": {"label": "Person", "name": "Pay"},
#         "relationship": "Pay is a product offered by the company"
#     },
#     {
#         "node_1": {"label": "Action", "name": "introduced"},
#         "node_2": {"label": "Document", "name": "collateral-free education financing"},
#         "relationship": "The company introduced collateral-free education financing"
#     },
#     {
#         "node_1": {"label": "Place", "name": "cities"},
#         "node_2": {"label": "Place", "name": "tier II and III"},
#         "relationship": "The cities are tier II and III"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:59 - INFO
# Trying JSON Parsing:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "NBFC"},
#         "node_2": {"label": "Organisation", "name": "company"},
#         "relationship": "NBFC is an arm of the company"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "company"},
#         "node_2": {"label": "Person", "name": "Pay"},
#         "relationship": "Pay is a product offered by the company"
#     },
#     {
#         "node_1": {"label": "Action", "name": "introduced"},
#         "node_2": {"label": "Document", "name": "collateral-free education financing"},
#         "relationship": "The company introduced collateral-free education financing"
#     },
#     {
#         "node_1": {"label": "Place", "name": "cities"},
#         "node_2": {"label": "Place", "name": "tier II and III"},
#         "relationship": "The cities are tier II and III"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:59 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:34:59 - INFO
# Waiting for 1s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:00 - INFO
# Document: 14
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:35:00 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives,this person will be associated or connected with a organization ,Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organisation', 'Action', {'Miscellaneous': 'Any important concept can not be categorised with any other given label'}] relationships=['Relation between any pair of Entities, every node should be having a relationship']
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:groq._base_client:Retrying request to /openai/v1/chat/completions in 1.000000 seconds
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:35:02 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Edgro"},
#         "node_2": {"label": "Organisation", "name": "Propelld"},
#         "relationship": "Edgro started its operations in July 2023, while Propelld has already raised nearly $40 million"
#     },
#     {
#         "node_1": {"label": "Person", "name": "students"},
#         "node_2": {"label": "Organisation", "name": "accredited lenders"},
#         "relationship": "students face difficulties in securing finances from accredited lenders"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "WestBridge Cap"},
#         "node_2": {"label": "Organisation", "name": "Propelld"},
#         "relationship": "WestBridge Cap is an investor of Propelld"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:02 - INFO
# Trying JSON Parsing:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Edgro"},
#         "node_2": {"label": "Organisation", "name": "Propelld"},
#         "relationship": "Edgro started its operations in July 2023, while Propelld has already raised nearly $40 million"
#     },
#     {
#         "node_1": {"label": "Person", "name": "students"},
#         "node_2": {"label": "Organisation", "name": "accredited lenders"},
#         "relationship": "students face difficulties in securing finances from accredited lenders"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "WestBridge Cap"},
#         "node_2": {"label": "Organisation", "name": "Propelld"},
#         "relationship": "WestBridge Cap is an investor of Propelld"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:02 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:02 - INFO
# Waiting for 1s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:03 - INFO
# Document: 15
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:35:03 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives,this person will be associated or connected with a organization ,Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organisation', 'Action', {'Miscellaneous': 'Any important concept can not be categorised with any other given label'}] relationships=['Relation between any pair of Entities, every node should be having a relationship']
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:groq._base_client:Retrying request to /openai/v1/chat/completions in 1.000000 seconds
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:35:05 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Propelld"},
#         "node_2": {"label": "Organisation", "name": "Stellaris Venture Partners"},
#         "relationship": "Propelld has received funding from Stellaris Venture Partners"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Propelld"},
#         "node_2": {"label": "Organisation", "name": "India Quotient"},
#         "relationship": "Propelld has received funding from India Quotient"
#     },
#     {
#         "node_1": {"label": "Person", "name": "Propelld"},
#         "node_2": {"label": "Organisation", "name": "Propelld"},
#         "relationship": "Propelld is an organisation"
#     },
#     {
#         "node_1": {"label": "Event", "name": "last funding round"},
#         "node_2": {"label": "Organisation", "name": "Propelld"},
#         "relationship": "The last funding round occurred at Propelld"
#     },
#     {
#         "node_1": {"label": "Event", "name": "last funding round"},
#         "node_2": {"label": "Date", "name": "February 2022"},
#         "relationship": "The last funding round occurred in February 2022"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Propelld"},
#         "node_2": {"label": "Object", "name": "annual loan disbursal"},
#         "relationship": "Propelld disburses annual loan"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:05 - INFO
# Trying JSON Parsing:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Propelld"},
#         "node_2": {"label": "Organisation", "name": "Stellaris Venture Partners"},
#         "relationship": "Propelld has received funding from Stellaris Venture Partners"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Propelld"},
#         "node_2": {"label": "Organisation", "name": "India Quotient"},
#         "relationship": "Propelld has received funding from India Quotient"
#     },
#     {
#         "node_1": {"label": "Person", "name": "Propelld"},
#         "node_2": {"label": "Organisation", "name": "Propelld"},
#         "relationship": "Propelld is an organisation"
#     },
#     {
#         "node_1": {"label": "Event", "name": "last funding round"},
#         "node_2": {"label": "Organisation", "name": "Propelld"},
#         "relationship": "The last funding round occurred at Propelld"
#     },
#     {
#         "node_1": {"label": "Event", "name": "last funding round"},
#         "node_2": {"label": "Date", "name": "February 2022"},
#         "relationship": "The last funding round occurred in February 2022"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Propelld"},
#         "node_2": {"label": "Object", "name": "annual loan disbursal"},
#         "relationship": "Propelld disburses annual loan"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:05 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:05 - INFO
# Waiting for 1s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:06 - INFO
# Document: 16
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:35:06 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives,this person will be associated or connected with a organization ,Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organisation', 'Action', {'Miscellaneous': 'Any important concept can not be categorised with any other given label'}] relationships=['Relation between any pair of Entities, every node should be having a relationship']
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:groq._base_client:Retrying request to /openai/v1/chat/completions in 1.000000 seconds
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:35:08 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Propelld"},
#         "node_2": {"label": "Organisation", "name": "TheKredible"},
#         "relationship": "Propelld is associated with TheKredible"
#     },
#     {
#         "node_1": {"label": "Person", "name": "Propelld"},
#         "node_2": {"label": "Person", "name": "Propelld"},
#         "relationship": "Propelld is the same entity"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Propelld"},
#         "node_2": {"label": "Object", "name": "Rs 75 crore"},
#         "relationship": "Propelld has revenue of Rs 75 crore"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Propelld"},
#         "node_2": {"label": "Object", "name": "Rs 33 crore"},
#         "relationship": "Propelld had revenue of Rs 33 crore"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:08 - INFO
# Trying JSON Parsing:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Propelld"},
#         "node_2": {"label": "Organisation", "name": "TheKredible"},
#         "relationship": "Propelld is associated with TheKredible"
#     },
#     {
#         "node_1": {"label": "Person", "name": "Propelld"},
#         "node_2": {"label": "Person", "name": "Propelld"},
#         "relationship": "Propelld is the same entity"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Propelld"},
#         "node_2": {"label": "Object", "name": "Rs 75 crore"},
#         "relationship": "Propelld has revenue of Rs 75 crore"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Propelld"},
#         "node_2": {"label": "Object", "name": "Rs 33 crore"},
#         "relationship": "Propelld had revenue of Rs 33 crore"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:08 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:08 - INFO
# Waiting for 1s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:09 - INFO
# Document: 17
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:35:09 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives,this person will be associated or connected with a organization ,Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organisation', 'Action', {'Miscellaneous': 'Any important concept can not be categorised with any other given label'}] relationships=['Relation between any pair of Entities, every node should be having a relationship']
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:groq._base_client:Retrying request to /openai/v1/chat/completions in 1.000000 seconds
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:35:11 - INFO
# LLM Response:
# [
#   {
#     "node_1": {"label": "Organisation", "name": "Propelld"},
#     "node_2": {"label": "Organisation", "name": "Leap Finance"},
#     "relationship": "Propelld competes with Leap Finance"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "Propelld"},
#     "node_2": {"label": "Organisation", "name": "Financepeer"},
#     "relationship": "Propelld competes with Financepeer"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "Propelld"},
#     "node_2": {"label": "Organisation", "name": "GrayQuest"},
#     "relationship": "Propelld competes with GrayQuest"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "Propelld"},
#     "node_2": {"label": "Organisation", "name": "Eduvanz"},
#     "relationship": "Propelld competes with Eduvanz"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "Propelld"},
#     "node_2": {"label": "Organisation", "name": "Auxilo"},
#     "relationship": "Propelld competes with Auxilo"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "Propelld"},
#     "node_2": {"label": "Organisation", "name": "MP"},
#     "relationship": "Propelld competes with MP"
#   }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:11 - INFO
# Trying JSON Parsing:
# [
#   {
#     "node_1": {"label": "Organisation", "name": "Propelld"},
#     "node_2": {"label": "Organisation", "name": "Leap Finance"},
#     "relationship": "Propelld competes with Leap Finance"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "Propelld"},
#     "node_2": {"label": "Organisation", "name": "Financepeer"},
#     "relationship": "Propelld competes with Financepeer"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "Propelld"},
#     "node_2": {"label": "Organisation", "name": "GrayQuest"},
#     "relationship": "Propelld competes with GrayQuest"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "Propelld"},
#     "node_2": {"label": "Organisation", "name": "Eduvanz"},
#     "relationship": "Propelld competes with Eduvanz"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "Propelld"},
#     "node_2": {"label": "Organisation", "name": "Auxilo"},
#     "relationship": "Propelld competes with Auxilo"
#   },
#   {
#     "node_1": {"label": "Organisation", "name": "Propelld"},
#     "node_2": {"label": "Organisation", "name": "MP"},
#     "relationship": "Propelld competes with MP"
#   }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:11 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:11 - INFO
# Waiting for 1s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:12 - INFO
# Document: 18
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:35:12 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives,this person will be associated or connected with a organization ,Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organisation', 'Action', {'Miscellaneous': 'Any important concept can not be categorised with any other given label'}] relationships=['Relation between any pair of Entities, every node should be having a relationship']
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:groq._base_client:Retrying request to /openai/v1/chat/completions in 1.000000 seconds
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:35:14 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Leap Finance"},
#         "node_2": {"label": "Organisation", "name": "Capital"},
#         "relationship": "Leap Finance received funding from Capital"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Leap Finance"},
#         "node_2": {"label": "Organisation", "name": "Credenc"},
#         "relationship": "Leap Finance and Credenc are both organisations"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Credenc"},
#         "node_2": {"label": "Organisation", "name": "Capital"},
#         "relationship": "Credenc received funding from Capital"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:14 - INFO
# Trying JSON Parsing:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Leap Finance"},
#         "node_2": {"label": "Organisation", "name": "Capital"},
#         "relationship": "Leap Finance received funding from Capital"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Leap Finance"},
#         "node_2": {"label": "Organisation", "name": "Credenc"},
#         "relationship": "Leap Finance and Credenc are both organisations"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Credenc"},
#         "node_2": {"label": "Organisation", "name": "Capital"},
#         "relationship": "Credenc received funding from Capital"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:14 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:14 - INFO
# Waiting for 1s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:15 - INFO
# Document: 19
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:35:15 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives,this person will be associated or connected with a organization ,Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organisation', 'Action', {'Miscellaneous': 'Any important concept can not be categorised with any other given label'}] relationships=['Relation between any pair of Entities, every node should be having a relationship']
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:groq._base_client:Retrying request to /openai/v1/chat/completions in 1.000000 seconds
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:35:17 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Eduvanz"},
#         "node_2": {"label": "Event", "name": "raised $12 million"},
#         "relationship": "Eduvanz raised $12 million"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "GrayQuest"},
#         "node_2": {"label": "Event", "name": "scored $7 million"},
#         "relationship": "GrayQuest scored $7 million"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Mpower Finance"},
#         "node_2": {"label": "Event", "name": "scored $150 million"},
#         "relationship": "Mpower Finance scored $150 million"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Auxilo"},
#         "node_2": {"label": "Event", "name": "raised $6"},
#         "relationship": "Auxilo raised $6"
#     },
#     {
#         "node_1": {"label": "Place", "name": "India"},
#         "node_2": {"label": "Event", "name": "July 2021"},
#         "relationship": "India was in July 2021"
#     },
#     {
#         "node_1": {"label": "Place", "name": "India"},
#         "node_2": {"label": "Event", "name": "December 2022"},
#         "relationship": "India was in December 2022"
#     },
#     {
#         "node_1": {"label": "Place", "name": "India"},
#         "node_2": {"label": "Event", "name": "2023"},
#         "relationship": "India was in 2023"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:17 - INFO
# Trying JSON Parsing:
# [
#     {
#         "node_1": {"label": "Organisation", "name": "Eduvanz"},
#         "node_2": {"label": "Event", "name": "raised $12 million"},
#         "relationship": "Eduvanz raised $12 million"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "GrayQuest"},
#         "node_2": {"label": "Event", "name": "scored $7 million"},
#         "relationship": "GrayQuest scored $7 million"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Mpower Finance"},
#         "node_2": {"label": "Event", "name": "scored $150 million"},
#         "relationship": "Mpower Finance scored $150 million"
#     },
#     {
#         "node_1": {"label": "Organisation", "name": "Auxilo"},
#         "node_2": {"label": "Event", "name": "raised $6"},
#         "relationship": "Auxilo raised $6"
#     },
#     {
#         "node_1": {"label": "Place", "name": "India"},
#         "node_2": {"label": "Event", "name": "July 2021"},
#         "relationship": "India was in July 2021"
#     },
#     {
#         "node_1": {"label": "Place", "name": "India"},
#         "node_2": {"label": "Event", "name": "December 2022"},
#         "relationship": "India was in December 2022"
#     },
#     {
#         "node_1": {"label": "Place", "name": "India"},
#         "node_2": {"label": "Event", "name": "2023"},
#         "relationship": "India was in 2023"
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:17 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:17 - INFO
# Waiting for 1s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:18 - INFO
# Document: 20
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:35:18 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives,this person will be associated or connected with a organization ,Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organisation', 'Action', {'Miscellaneous': 'Any important concept can not be categorised with any other given label'}] relationships=['Relation between any pair of Entities, every node should be having a relationship']
# Using Model:  llama3-8b-8192
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:groq._base_client:Retrying request to /openai/v1/chat/completions in 1.000000 seconds
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-19 13:35:20 - INFO
# LLM Response:
# [
#   {
#     "node_1": {
#       "label": "Person",
#       "name": "million"
#     },
#     "node_2": {
#       "label": "Object",
#       "name": "debt"
#     },
#     "relationship": "The person is in debt."
#   }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:20 - INFO
# Trying JSON Parsing:
# [
#   {
#     "node_1": {
#       "label": "Person",
#       "name": "million"
#     },
#     "node_2": {
#       "label": "Object",
#       "name": "debt"
#     },
#     "relationship": "The person is in debt."
#   }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:20 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-19 13:35:20 - INFO
# Waiting for 1s before the next request ...
# Total number of Edges 85

# %%
from pprint import pprint
for edge in graph:
    print(edge.model_dump(exclude=['metadata']), "\n\n")
# Out:
# {'node_1': {'label': 'Organisation', 'name': 'Stanza Living'}, 'node_2': {'label': 'Organisation', 'name': 'Alpha Wave'}, 'relationship': 'Stanza Living has received investment from Alpha Wave', 'order': 0}
#
#
# {'node_1': {'label': 'Person', 'name': 'Stanza Living'}, 'node_2': {'label': 'Event', 'name': 'equity round'}, 'relationship': 'Stanza Living has participated in an equity round', 'order': 0}
#
#
# {'node_1': {'label': 'Person', 'name': 'Stanza Living'}, 'node_2': {'label': 'Object', 'name': 'Rs 110 crore'}, 'relationship': 'Stanza Living has received Rs 110 crore', 'order': 0}
#
#
# {'node_1': {'label': 'Person', 'name': 'Stanza Living'}, 'node_2': {'label': 'Action', 'name': 'raised'}, 'relationship': 'Stanza Living has raised funds', 'order': 0}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Stanza Living'}, 'node_2': {'label': 'Organisation', 'name': 'Delhi-based startup'}, 'relationship': 'Stanza Living is associated with the Delhi-based startup', 'order': 1}
#
#
# {'node_1': {'label': 'Person', 'name': 'board'}, 'node_2': {'label': 'Organisation', 'name': 'Stanza Living'}, 'relationship': 'The board is part of Stanza Living', 'order': 1}
#
#
# {'node_1': {'label': 'Event', 'name': 'passing a special resolution'}, 'node_2': {'label': 'Organisation', 'name': 'Stanza Living'}, 'relationship': 'Stanza Living passed a special resolution', 'order': 1}
#
#
# {'node_1': {'label': 'Object', 'name': '1,207 preference shares'}, 'node_2': {'label': 'Organisation', 'name': 'Stanza Living'}, 'relationship': 'Stanza Living issued 1,207 preference shares', 'order': 1}
#
#
# {'node_1': {'label': 'Object', 'name': 'Rs 911440.17'}, 'node_2': {'label': 'Object', 'name': 'Rs 110 crore'}, 'relationship': 'Rs 911440.17 is the price of Rs 110 crore', 'order': 1}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Alpha Wave'}, 'node_2': {'label': 'Organisation', 'name': 'Matrix Partners'}, 'relationship': 'Alpha Wave has invested in Matrix Partners', 'order': 2}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Alpha Wave'}, 'node_2': {'label': 'Organisation', 'name': 'Accel India'}, 'relationship': 'Alpha Wave has invested in Accel India', 'order': 2}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Alpha Wave'}, 'node_2': {'label': 'Organisation', 'name': 'Peak XV'}, 'relationship': 'Alpha Wave has invested in Peak XV', 'order': 2}
#
#
# {'node_1': {'label': 'Person', 'name': 'g'}, 'node_2': {'label': 'Document', 'name': 'startup data'}, 'relationship': 'g accessed startup data', 'order': 2}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'TheKredible'}, 'node_2': {'label': 'Organisation', 'name': 'Stanza Living'}, 'relationship': 'TheKredible is associated with Stanza Living', 'order': 3}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'TheKredible'}, 'node_2': {'label': 'Object', 'name': 'Rs 3,900 crore'}, 'relationship': 'TheKredible is valued at Rs 3,900 crore', 'order': 3}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'TheKredible'}, 'node_2': {'label': 'Object', 'name': 'Rs 3,525 crore'}, 'relationship': 'TheKredible was valued at Rs 3,525 crore in the last equity round', 'order': 3}
#
#
# {'node_1': {'label': 'Object', 'name': 'Rs 3,900 crore'}, 'node_2': {'label': 'Object', 'name': 'Rs 3,525 crore'}, 'relationship': 'Rs 3,900 crore is a marginal jump in valuation from Rs 3,525 crore', 'order': 3}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Stanza Living'}, 'node_2': {'label': 'Organisation', 'name': 'Kotak Mahindra Bank'}, 'relationship': 'Stanza Living has a financial relationship with Kotak Mahindra Bank', 'order': 4}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Stanza Living'}, 'node_2': {'label': 'Organisation', 'name': 'RBL Bank'}, 'relationship': 'Stanza Living has a financial relationship with RBL Bank', 'order': 4}
#
#
# {'node_1': {'label': 'Person', 'name': 'unknown'}, 'node_2': {'label': 'Organisation', 'name': 'Stanza Living'}, 'relationship': 'The person was reportedly in talks to raise funding for Stanza Living', 'order': 4}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Stanza Living'}, 'node_2': {'label': 'Event', 'name': 'equity round'}, 'relationship': 'Stanza Living participated in an equity round', 'order': 5}
#
#
# {'node_1': {'label': 'Person', 'name': 'unknown'}, 'node_2': {'label': 'Organisation', 'name': 'Stanza Living'}, 'relationship': 'The person is associated with Stanza Living', 'order': 5}
#
#
# {'node_1': {'label': 'Object', 'name': 'equity round'}, 'node_2': {'label': 'Object', 'name': 'debt rounds'}, 'relationship': 'Equity round is related to debt rounds', 'order': 5}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Stanza Living'}, 'node_2': {'label': 'Place', 'name': 'unknown'}, 'relationship': 'Stanza Living operates in a place', 'order': 5}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Stanza Living'}, 'node_2': {'label': 'Organisation', 'name': 'The firm'}, 'relationship': 'Stanza Living is the same as The firm', 'order': 6}
#
#
# {'node_1': {'label': 'Person', 'name': 'professionals'}, 'node_2': {'label': 'Person', 'name': 'students'}, 'relationship': 'professionals and students are two groups of people', 'order': 6}
#
#
# {'node_1': {'label': 'Object', 'name': '75,000 beds'}, 'node_2': {'label': 'Object', 'name': '450 plus residences'}, 'relationship': '75,000 beds and 450 plus residences are two different objects', 'order': 6}
#
#
# {'node_1': {'label': 'Place', 'name': '24 cities'}, 'node_2': {'label': 'Organisation', 'name': 'Stanza Living'}, 'relationship': 'Stanza Living has a presence across 24 cities', 'order': 6}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'TheKredible'}, 'node_2': {'label': 'Organisation', 'name': 'The firm'}, 'relationship': 'TheKredible is related to the firm', 'order': 7}
#
#
# {'node_1': {'label': 'Person', 'name': 's'}, 'node_2': {'label': 'Organisation', 'name': 'TheKredible'}, 'relationship': 's is associated with TheKredible', 'order': 7}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'TheKredible'}, 'node_2': {'label': 'Event', 'name': 'FY23'}, 'relationship': 'TheKredible is involved in FY23', 'order': 7}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'TheKredible'}, 'node_2': {'label': 'Event', 'name': 'FY22'}, 'relationship': 'TheKredible is involved in FY22', 'order': 7}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'TheKredible'}, 'node_2': {'label': 'Action', 'name': 'file'}, 'relationship': 'TheKredible needs to file', 'order': 7}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Stanza Living'}, 'node_2': {'label': 'Organisation', 'name': 'Colive'}, 'relationship': 'Stanza Living competes with Colive', 'order': 8}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Stanza Living'}, 'node_2': {'label': 'Organisation', 'name': 'Your Space'}, 'relationship': 'Stanza Living competes with Your Space', 'order': 8}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Stanza Living'}, 'node_2': {'label': 'Organisation', 'name': 'Settl'}, 'relationship': 'Stanza Living competes with Settl', 'order': 8}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Stanza Living'}, 'node_2': {'label': 'Organisation', 'name': 'Union Living'}, 'relationship': 'Stanza Living competes with Union Living', 'order': 8}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Stanza Living'}, 'node_2': {'label': 'Organisation', 'name': 'Coho'}, 'relationship': 'Stanza Living competes with Coho', 'order': 8}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'NestAway'}, 'node_2': {'label': 'Organisation', 'name': 'Aurum PropTech'}, 'relationship': 'NestAway was acquired by Aurum PropTech', 'order': 8}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Majesco Ltd'}, 'node_2': {'label': 'Organisation', 'name': 'Propelld'}, 'relationship': 'Majesco Ltd is related to Propelld as an investor', 'order': 9}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Propelld'}, 'node_2': {'label': 'Organisation', 'name': 'Edgro'}, 'relationship': 'Propelld owns Edgro', 'order': 9}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Edgro'}, 'node_2': {'label': 'Object', 'name': 'NBFC subsidiary'}, 'relationship': 'Edgro is a type of NBFC subsidiary', 'order': 9}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Propelld'}, 'node_2': {'label': 'Object', 'name': '$25 million debt funding'}, 'relationship': 'Propelld received $25 million debt funding', 'order': 9}
#
#
# {'node_1': {'label': 'Person', 'name': 'dgro'}, 'node_2': {'label': 'Organisation', 'name': 'Credit Saison India Private Limited'}, 'relationship': 'dgro is associated with Credit Saison India Private Limited', 'order': 10}
#
#
# {'node_1': {'label': 'Person', 'name': 'dgro'}, 'node_2': {'label': 'Organisation', 'name': 'AU Small Finance Bank'}, 'relationship': 'dgro is associated with AU Small Finance Bank', 'order': 10}
#
#
# {'node_1': {'label': 'Person', 'name': 'dgro'}, 'node_2': {'label': 'Organisation', 'name': 'InCred Financial Services Limited'}, 'relationship': 'dgro is associated with InCred Financial Services Limited', 'order': 10}
#
#
# {'node_1': {'label': 'Person', 'name': 'dgro'}, 'node_2': {'label': 'Organisation', 'name': 'Northern Arc Capital Limited'}, 'relationship': 'dgro is associated with Northern Arc Capital Limited', 'order': 10}
#
#
# {'node_1': {'label': 'Person', 'name': 'Bibhu Prasad Das'}, 'node_2': {'label': 'Organisation', 'name': 'Propelld'}, 'relationship': 'Bibhu Prasad Das is a co-founder of Propelld', 'order': 11}
#
#
# {'node_1': {'label': 'Person', 'name': 'Victor Senapaty'}, 'node_2': {'label': 'Organisation', 'name': 'Propelld'}, 'relationship': 'Victor Senapaty is a co-founder of Propelld', 'order': 11}
#
#
# {'node_1': {'label': 'Person', 'name': 'Brijesh Samantaray'}, 'node_2': {'label': 'Organisation', 'name': 'Propelld'}, 'relationship': 'Brijesh Samantaray is a co-founder of Propelld', 'order': 11}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Propelld'}, 'node_2': {'label': 'Event', 'name': 'Founded'}, 'relationship': 'Propelld was founded', 'order': 11}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'NBFC'}, 'node_2': {'label': 'Organisation', 'name': 'company'}, 'relationship': 'NBFC is an arm of the company', 'order': 12}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'company'}, 'node_2': {'label': 'Person', 'name': 'Pay'}, 'relationship': 'Pay is a product offered by the company', 'order': 12}
#
#
# {'node_1': {'label': 'Action', 'name': 'introduced'}, 'node_2': {'label': 'Document', 'name': 'collateral-free education financing'}, 'relationship': 'The company introduced collateral-free education financing', 'order': 12}
#
#
# {'node_1': {'label': 'Place', 'name': 'cities'}, 'node_2': {'label': 'Place', 'name': 'tier II and III'}, 'relationship': 'The cities are tier II and III', 'order': 12}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Edgro'}, 'node_2': {'label': 'Organisation', 'name': 'Propelld'}, 'relationship': 'Edgro started its operations in July 2023, while Propelld has already raised nearly $40 million', 'order': 13}
#
#
# {'node_1': {'label': 'Person', 'name': 'students'}, 'node_2': {'label': 'Organisation', 'name': 'accredited lenders'}, 'relationship': 'students face difficulties in securing finances from accredited lenders', 'order': 13}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'WestBridge Cap'}, 'node_2': {'label': 'Organisation', 'name': 'Propelld'}, 'relationship': 'WestBridge Cap is an investor of Propelld', 'order': 13}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Propelld'}, 'node_2': {'label': 'Organisation', 'name': 'Stellaris Venture Partners'}, 'relationship': 'Propelld has received funding from Stellaris Venture Partners', 'order': 14}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Propelld'}, 'node_2': {'label': 'Organisation', 'name': 'India Quotient'}, 'relationship': 'Propelld has received funding from India Quotient', 'order': 14}
#
#
# {'node_1': {'label': 'Person', 'name': 'Propelld'}, 'node_2': {'label': 'Organisation', 'name': 'Propelld'}, 'relationship': 'Propelld is an organisation', 'order': 14}
#
#
# {'node_1': {'label': 'Event', 'name': 'last funding round'}, 'node_2': {'label': 'Organisation', 'name': 'Propelld'}, 'relationship': 'The last funding round occurred at Propelld', 'order': 14}
#
#
# {'node_1': {'label': 'Event', 'name': 'last funding round'}, 'node_2': {'label': 'Date', 'name': 'February 2022'}, 'relationship': 'The last funding round occurred in February 2022', 'order': 14}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Propelld'}, 'node_2': {'label': 'Object', 'name': 'annual loan disbursal'}, 'relationship': 'Propelld disburses annual loan', 'order': 14}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Propelld'}, 'node_2': {'label': 'Organisation', 'name': 'TheKredible'}, 'relationship': 'Propelld is associated with TheKredible', 'order': 15}
#
#
# {'node_1': {'label': 'Person', 'name': 'Propelld'}, 'node_2': {'label': 'Person', 'name': 'Propelld'}, 'relationship': 'Propelld is the same entity', 'order': 15}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Propelld'}, 'node_2': {'label': 'Object', 'name': 'Rs 75 crore'}, 'relationship': 'Propelld has revenue of Rs 75 crore', 'order': 15}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Propelld'}, 'node_2': {'label': 'Object', 'name': 'Rs 33 crore'}, 'relationship': 'Propelld had revenue of Rs 33 crore', 'order': 15}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Propelld'}, 'node_2': {'label': 'Organisation', 'name': 'Leap Finance'}, 'relationship': 'Propelld competes with Leap Finance', 'order': 16}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Propelld'}, 'node_2': {'label': 'Organisation', 'name': 'Financepeer'}, 'relationship': 'Propelld competes with Financepeer', 'order': 16}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Propelld'}, 'node_2': {'label': 'Organisation', 'name': 'GrayQuest'}, 'relationship': 'Propelld competes with GrayQuest', 'order': 16}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Propelld'}, 'node_2': {'label': 'Organisation', 'name': 'Eduvanz'}, 'relationship': 'Propelld competes with Eduvanz', 'order': 16}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Propelld'}, 'node_2': {'label': 'Organisation', 'name': 'Auxilo'}, 'relationship': 'Propelld competes with Auxilo', 'order': 16}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Propelld'}, 'node_2': {'label': 'Organisation', 'name': 'MP'}, 'relationship': 'Propelld competes with MP', 'order': 16}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Leap Finance'}, 'node_2': {'label': 'Organisation', 'name': 'Capital'}, 'relationship': 'Leap Finance received funding from Capital', 'order': 17}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Leap Finance'}, 'node_2': {'label': 'Organisation', 'name': 'Credenc'}, 'relationship': 'Leap Finance and Credenc are both organisations', 'order': 17}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Credenc'}, 'node_2': {'label': 'Organisation', 'name': 'Capital'}, 'relationship': 'Credenc received funding from Capital', 'order': 17}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Eduvanz'}, 'node_2': {'label': 'Event', 'name': 'raised $12 million'}, 'relationship': 'Eduvanz raised $12 million', 'order': 18}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'GrayQuest'}, 'node_2': {'label': 'Event', 'name': 'scored $7 million'}, 'relationship': 'GrayQuest scored $7 million', 'order': 18}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Mpower Finance'}, 'node_2': {'label': 'Event', 'name': 'scored $150 million'}, 'relationship': 'Mpower Finance scored $150 million', 'order': 18}
#
#
# {'node_1': {'label': 'Organisation', 'name': 'Auxilo'}, 'node_2': {'label': 'Event', 'name': 'raised $6'}, 'relationship': 'Auxilo raised $6', 'order': 18}
#
#
# {'node_1': {'label': 'Place', 'name': 'India'}, 'node_2': {'label': 'Event', 'name': 'July 2021'}, 'relationship': 'India was in July 2021', 'order': 18}
#
#
# {'node_1': {'label': 'Place', 'name': 'India'}, 'node_2': {'label': 'Event', 'name': 'December 2022'}, 'relationship': 'India was in December 2022', 'order': 18}
#
#
# {'node_1': {'label': 'Place', 'name': 'India'}, 'node_2': {'label': 'Event', 'name': '2023'}, 'relationship': 'India was in 2023', 'order': 18}
#
#
# {'node_1': {'label': 'Person', 'name': 'million'}, 'node_2': {'label': 'Object', 'name': 'debt'}, 'relationship': 'The person is in debt.', 'order': 19}

# %% [markdown]
# ### Save graph in neo4j

# %%
from graph_maker import Neo4jGraphModel

create_indices = False
neo4j_graph = Neo4jGraphModel(edges=graph, create_indices=create_indices)

neo4j_graph.save()
# Out:
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# aenter called
# aexit called
# 85
